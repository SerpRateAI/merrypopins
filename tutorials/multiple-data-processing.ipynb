# %% [markdown]
# # Multiple Data Processing Tutorial

# %%
# Change to project root (parent directory) This step is necessary to ensure that the script runs from the correct context.
# %cd ..

from pathlib import Path

# Check if current directory is 'merrypopins'
if Path.cwd().name != "merrypopins":
    print("Error: You are not in the project root directory.")
    print("Please change to the project root directory and try again.")
# Out:
# /Users/cacar/Desktop/University Documents and Books/Utrecht-Uni-Master-Applied-Data-Science/Thesis/merrypopins

# %% [markdown]
# ## Installation

# %% [markdown]
# If you already have `merrypopins` installed, you can skip this step.

# %%
# !python3 -m pip install --upgrade pip
# !pip uninstall merrypopins -y
# !python3 -m pip install -e .
# Out:
# Requirement already satisfied: pip in /opt/anaconda3/lib/python3.12/site-packages (25.1.1)
# Found existing installation: merrypopins 0.1.1
# Uninstalling merrypopins-0.1.1:
#   Successfully uninstalled merrypopins-0.1.1
# Obtaining file:///Users/cacar/Desktop/University%20Documents%20and%20Books/Utrecht-Uni-Master-Applied-Data-Science/Thesis/merrypopins
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy<2.5,>=1.23 in /opt/anaconda3/lib/python3.12/site-packages (from merrypopins==0.1.1) (1.26.4)
# Requirement already satisfied: pandas>=2.2.3 in /opt/anaconda3/lib/python3.12/site-packages (from merrypopins==0.1.1) (2.2.3)
# Requirement already satisfied: scipy>=1.15.3 in /opt/anaconda3/lib/python3.12/site-packages (from merrypopins==0.1.1) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.6.1 in /opt/anaconda3/lib/python3.12/site-packages (from merrypopins==0.1.1) (1.6.1)
# Requirement already satisfied: tensorflow>=2.16.2 in /opt/anaconda3/lib/python3.12/site-packages (from merrypopins==0.1.1) (2.16.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=2.2.3->merrypopins==0.1.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=2.2.3->merrypopins==0.1.1) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=2.2.3->merrypopins==0.1.1) (2024.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.2.3->merrypopins==0.1.1) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=1.6.1->merrypopins==0.1.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=1.6.1->merrypopins==0.1.1) (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.1.1) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.1.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.1.1) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.1.1) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.1.1) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.1.1) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.1.1) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.1.1) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.1.1) (3.4.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.1.1) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.1.1) (4.25.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.1.1) (2.32.3)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.1.1) (75.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.1.1) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.1.1) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.1.1) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.1.1) (1.69.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.1.1) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.1.1) (3.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow>=2.16.2->merrypopins==0.1.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow>=2.16.2->merrypopins==0.1.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow>=2.16.2->merrypopins==0.1.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow>=2.16.2->merrypopins==0.1.1) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.16.2->merrypopins==0.1.1) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.16.2->merrypopins==0.1.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.16.2->merrypopins==0.1.1) (3.0.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow>=2.16.2->merrypopins==0.1.1) (0.44.0)
# Requirement already satisfied: rich in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow>=2.16.2->merrypopins==0.1.1) (13.9.4)
# Requirement already satisfied: namex in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow>=2.16.2->merrypopins==0.1.1) (0.0.8)
# Requirement already satisfied: optree in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow>=2.16.2->merrypopins==0.1.1) (0.13.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow>=2.16.2->merrypopins==0.1.1) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow>=2.16.2->merrypopins==0.1.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow>=2.16.2->merrypopins==0.1.1) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow>=2.16.2->merrypopins==0.1.1) (0.1.0)
# Building wheels for collected packages: merrypopins
#   Building editable for merrypopins (pyproject.toml) ... done
#   Created wheel for merrypopins: filename=merrypopins-0.1.1-0.editable-py3-none-any.whl size=17514 sha256=7d3649da08091176205be84f603f3e7f103ff8e488338dd69ec84a974a3856ee
#   Stored in directory: /private/var/folders/bg/vndfz9xx467c3blfn0k7mlbc0000gn/T/pip-ephem-wheel-cache-xzlegzvj/wheels/82/0f/fb/e0ceb84d648e8984895addbac076998d8e2027912ad09ba4e4
# Successfully built merrypopins
# Installing collected packages: merrypopins
# Successfully installed merrypopins-0.1.1

# %% [markdown]
# ## Importing Libraries

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
from PIL import Image
import math
from pathlib import Path
from merrypopins.make_dataset import merrypopins_pipeline

# %% [markdown]
# ## Define the Datasets Folder and the Output Folder for Visualizations

# %%
# Directory containing all the txt files
data_dir = Path("datasets/6microntip_slowloading")
output_dir = Path("outputs/6microntip_slowloading")

# %%
# Make sure output directory exists
output_dir.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Run the MerryPopins Pipeline

# %%
# Loop through all txt files in the dataset directory
for txt_file in data_dir.glob("*.txt"):
    print(f"Processing {txt_file.name}...")
    try:
        df_loc = merrypopins_pipeline(
            txt_path=txt_file,
            save_plot_dir=output_dir,
            trim_margin=30
        )
        print(f"✅ Done: {txt_file.name} (Pop-ins detected: {df_loc['popin'].sum()})")
    except Exception as e:
        print(f"❌ Failed: {txt_file.name} with error: {e}")
# Out:
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain4_6um_indent01_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain4_6um_indent01_HL_QS_LC.txt: 16394 × 3
# [INFO] Removed first 255 points up to minimum Load (-219.87)
# [INFO] Auto-rescaled at index 1243, load=106.17 > 71.59, shift=-27.8 nm
# [INFO] Flagged contact point at index 1243
# [INFO] Removed 1243 rows before contact point (Depth < 0)
# Processing grain4_6um_indent01_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 13 anomalies
# [INFO] CNN flagged 160 anomalies
# [INFO] Fourier spectral method flagged 39 anomalies
# [INFO] Savitzky-Golay flagged 0 anomalies
# [INFO] Total pop-ins detected by selected methods: 207
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain2_6um_indent02_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain2_6um_indent02_HL_QS_LC.txt: 16357 × 3
# [INFO] Removed first 896 points up to minimum Load (-381.00)
# [INFO] Auto-rescaled at index 562, load=-28.89 > -55.39, shift=-33.8 nm
# [INFO] Flagged contact point at index 562
# [INFO] Removed 562 rows before contact point (Depth < 0)
# ✅ Done: grain4_6um_indent01_HL_QS_LC.txt (Pop-ins detected: 207)
# Processing grain2_6um_indent02_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 15 anomalies
# [INFO] CNN flagged 155 anomalies
# [INFO] Fourier spectral method flagged 106 anomalies
# [INFO] Savitzky-Golay flagged 2 anomalies
# [INFO] Total pop-ins detected by selected methods: 267
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain5_6um_indent03_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain5_6um_indent03_HL_QS_LC.txt: 16396 × 3
# [INFO] Removed first 433 points up to minimum Load (-40.63)
# [INFO] Auto-rescaled at index 1067, load=277.92 > 244.51, shift=-28.1 nm
# [INFO] Flagged contact point at index 1067
# [INFO] Removed 1067 rows before contact point (Depth < 0)
# ✅ Done: grain2_6um_indent02_HL_QS_LC.txt (Pop-ins detected: 267)
# Processing grain5_6um_indent03_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 14 anomalies
# [INFO] CNN flagged 63 anomalies
# [INFO] Fourier spectral method flagged 38 anomalies
# [INFO] Savitzky-Golay flagged 12 anomalies
# [INFO] Total pop-ins detected by selected methods: 120
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain2_6um_indent03_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain2_6um_indent03_HL_QS_LC.txt: 16393 × 3
# [INFO] Removed first 238 points up to minimum Load (-5.19)
# [INFO] Auto-rescaled at index 1260, load=463.00 > 446.06, shift=-26.7 nm
# [INFO] Flagged contact point at index 1260
# [INFO] Removed 1260 rows before contact point (Depth < 0)
# ✅ Done: grain5_6um_indent03_HL_QS_LC.txt (Pop-ins detected: 120)
# Processing grain2_6um_indent03_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 14 anomalies
# [INFO] CNN flagged 132 anomalies
# [INFO] Fourier spectral method flagged 75 anomalies
# [INFO] Savitzky-Golay flagged 18 anomalies
# [INFO] Total pop-ins detected by selected methods: 233
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain5_6um_indent02_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain5_6um_indent02_HL_QS_LC.txt: 16392 × 3
# [INFO] Removed first 948 points up to minimum Load (-116.20)
# [INFO] Auto-rescaled at index 547, load=125.56 > 117.76, shift=-29.5 nm
# [INFO] Flagged contact point at index 547
# [INFO] Removed 547 rows before contact point (Depth < 0)
# ✅ Done: grain2_6um_indent03_HL_QS_LC.txt (Pop-ins detected: 233)
# Processing grain5_6um_indent02_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 13 anomalies
# [INFO] CNN flagged 64 anomalies
# [INFO] Fourier spectral method flagged 35 anomalies
# [INFO] Savitzky-Golay flagged 29 anomalies
# [INFO] Total pop-ins detected by selected methods: 120
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain3_6um_indent01_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain3_6um_indent01_HL_QS_LC.txt: 16378 × 3
# [INFO] Removed first 496 points up to minimum Load (-282.99)
# [INFO] Auto-rescaled at index 988, load=263.24 > 213.26, shift=-24.1 nm
# [INFO] Flagged contact point at index 988
# [INFO] Removed 988 rows before contact point (Depth < 0)
# ✅ Done: grain5_6um_indent02_HL_QS_LC.txt (Pop-ins detected: 120)
# Processing grain3_6um_indent01_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 15 anomalies
# [INFO] CNN flagged 107 anomalies
# [INFO] Fourier spectral method flagged 93 anomalies
# [INFO] Savitzky-Golay flagged 19 anomalies
# [INFO] Total pop-ins detected by selected methods: 223
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain6_6um_indent01_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain6_6um_indent01_HL_QS_LC.txt: 16383 × 3
# [INFO] Removed first 867 points up to minimum Load (-68.31)
# [INFO] Auto-rescaled at index 622, load=259.61 > 256.74, shift=-23.4 nm
# [INFO] Flagged contact point at index 622
# [INFO] Removed 622 rows before contact point (Depth < 0)
# ✅ Done: grain3_6um_indent01_HL_QS_LC.txt (Pop-ins detected: 223)
# Processing grain6_6um_indent01_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 15 anomalies
# [INFO] CNN flagged 101 anomalies
# [INFO] Fourier spectral method flagged 42 anomalies
# [INFO] Savitzky-Golay flagged 0 anomalies
# [INFO] Total pop-ins detected by selected methods: 154
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain8_6um_indent02_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain8_6um_indent02_HL_QS_LC.txt: 16398 × 3
# [INFO] Removed first 923 points up to minimum Load (-112.28)
# [INFO] Auto-rescaled at index 581, load=166.70 > 158.03, shift=6.5 nm
# [INFO] Flagged contact point at index 581
# [INFO] Removed 581 rows before contact point (Depth < 0)
# ✅ Done: grain6_6um_indent01_HL_QS_LC.txt (Pop-ins detected: 154)
# Processing grain8_6um_indent02_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 15 anomalies
# [INFO] CNN flagged 151 anomalies
# [INFO] Fourier spectral method flagged 13 anomalies
# [INFO] Savitzky-Golay flagged 19 anomalies
# [INFO] Total pop-ins detected by selected methods: 183
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain7_6um_indent03_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain7_6um_indent03_HL_QS_LC.txt: 16393 × 3
# [INFO] Removed first 144 points up to minimum Load (-132.29)
# [INFO] Auto-rescaled at index 1355, load=221.27 > 161.74, shift=7.2 nm
# [INFO] Flagged contact point at index 1355
# [INFO] Removed 1355 rows before contact point (Depth < 0)
# ✅ Done: grain8_6um_indent02_HL_QS_LC.txt (Pop-ins detected: 183)
# Processing grain7_6um_indent03_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 15 anomalies
# [INFO] CNN flagged 66 anomalies
# [INFO] Fourier spectral method flagged 27 anomalies
# [INFO] Savitzky-Golay flagged 16 anomalies
# [INFO] Total pop-ins detected by selected methods: 111
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain8_6um_indent03_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain8_6um_indent03_HL_QS_LC.txt: 16399 × 3
# [INFO] Removed first 369 points up to minimum Load (-128.54)
# [INFO] Auto-rescaled at index 1137, load=187.38 > 148.22, shift=7.2 nm
# [INFO] Flagged contact point at index 1137
# [INFO] Removed 1137 rows before contact point (Depth < 0)
# ✅ Done: grain7_6um_indent03_HL_QS_LC.txt (Pop-ins detected: 111)
# Processing grain8_6um_indent03_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 15 anomalies
# [INFO] CNN flagged 119 anomalies
# [INFO] Fourier spectral method flagged 34 anomalies
# [INFO] Savitzky-Golay flagged 12 anomalies
# [INFO] Total pop-ins detected by selected methods: 171
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain9_6um_indent01_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain9_6um_indent01_HL_QS_LC.txt: 16392 × 3
# [INFO] Removed first 321 points up to minimum Load (-125.44)
# [INFO] Auto-rescaled at index 1176, load=179.49 > 168.20, shift=7.4 nm
# [INFO] Flagged contact point at index 1176
# [INFO] Removed 1176 rows before contact point (Depth < 0)
# ✅ Done: grain8_6um_indent03_HL_QS_LC.txt (Pop-ins detected: 171)
# Processing grain9_6um_indent01_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 15 anomalies
# [INFO] CNN flagged 3 anomalies
# [INFO] Fourier spectral method flagged 40 anomalies
# [INFO] Savitzky-Golay flagged 0 anomalies
# [INFO] Total pop-ins detected by selected methods: 58
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain7_6um_indent02_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain7_6um_indent02_HL_QS_LC.txt: 16390 × 3
# [INFO] Removed first 833 points up to minimum Load (-102.57)
# [INFO] Auto-rescaled at index 663, load=157.14 > 153.75, shift=5.9 nm
# [INFO] Flagged contact point at index 663
# [INFO] Removed 663 rows before contact point (Depth < 0)
# ✅ Done: grain9_6um_indent01_HL_QS_LC.txt (Pop-ins detected: 58)
# Processing grain7_6um_indent02_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 14 anomalies
# [INFO] CNN flagged 74 anomalies
# [INFO] Fourier spectral method flagged 30 anomalies
# [INFO] Savitzky-Golay flagged 0 anomalies
# [INFO] Total pop-ins detected by selected methods: 117
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain1_6um_indent01_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain1_6um_indent01_HL_QS_LC.txt: 16390 × 3
# [INFO] Removed first 476 points up to minimum Load (40.42)
# [INFO] Auto-rescaled at index 1024, load=850.00 > 795.55, shift=-17.5 nm
# [INFO] Flagged contact point at index 1024
# [INFO] Removed 1024 rows before contact point (Depth < 0)
# ✅ Done: grain7_6um_indent02_HL_QS_LC.txt (Pop-ins detected: 117)
# Processing grain1_6um_indent01_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 14 anomalies
# [INFO] CNN flagged 50 anomalies
# [INFO] Fourier spectral method flagged 58 anomalies
# [INFO] Savitzky-Golay flagged 17 anomalies
# [INFO] Total pop-ins detected by selected methods: 135
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain8_6um_indent01_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain8_6um_indent01_HL_QS_LC.txt: 16403 × 3
# [INFO] Removed first 894 points up to minimum Load (-148.77)
# [INFO] Auto-rescaled at index 615, load=177.38 > 163.67, shift=7.1 nm
# [INFO] Flagged contact point at index 615
# [INFO] Removed 615 rows before contact point (Depth < 0)
# ✅ Done: grain1_6um_indent01_HL_QS_LC.txt (Pop-ins detected: 135)
# Processing grain8_6um_indent01_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 13 anomalies
# [INFO] CNN flagged 47 anomalies
# [INFO] Fourier spectral method flagged 21 anomalies
# [INFO] Savitzky-Golay flagged 19 anomalies
# [INFO] Total pop-ins detected by selected methods: 86
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain6_6um_indent02_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain6_6um_indent02_HL_QS_LC.txt: 16393 × 3
# [INFO] Removed first 258 points up to minimum Load (-155.22)
# [INFO] Auto-rescaled at index 1242, load=240.76 > 194.01, shift=-21.7 nm
# [INFO] Flagged contact point at index 1242
# [INFO] Removed 1242 rows before contact point (Depth < 0)
# ✅ Done: grain8_6um_indent01_HL_QS_LC.txt (Pop-ins detected: 86)
# Processing grain6_6um_indent02_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 14 anomalies
# [INFO] CNN flagged 58 anomalies
# [INFO] Fourier spectral method flagged 23 anomalies
# [INFO] Savitzky-Golay flagged 16 anomalies
# [INFO] Total pop-ins detected by selected methods: 99
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain10_6um_indent04_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain10_6um_indent04_HL_QS_LC.txt: 16378 × 3
# [INFO] Removed first 685 points up to minimum Load (-79.68)
# [INFO] Auto-rescaled at index 796, load=171.43 > 158.26, shift=-29.5 nm
# [INFO] Flagged contact point at index 796
# [INFO] Removed 796 rows before contact point (Depth < 0)
# ✅ Done: grain6_6um_indent02_HL_QS_LC.txt (Pop-ins detected: 99)
# Processing grain10_6um_indent04_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 15 anomalies
# [INFO] CNN flagged 74 anomalies
# [INFO] Fourier spectral method flagged 51 anomalies
# [INFO] Savitzky-Golay flagged 0 anomalies
# [INFO] Total pop-ins detected by selected methods: 137
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain10_6um_indent03_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain10_6um_indent03_HL_QS_LC.txt: 16369 × 3
# [INFO] Removed first 744 points up to minimum Load (-208.20)
# [INFO] Auto-rescaled at index 728, load=42.00 > 3.72, shift=-29.5 nm
# [INFO] Flagged contact point at index 728
# [INFO] Removed 728 rows before contact point (Depth < 0)
# ✅ Done: grain10_6um_indent04_HL_QS_LC.txt (Pop-ins detected: 137)
# Processing grain10_6um_indent03_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 15 anomalies
# [INFO] CNN flagged 77 anomalies
# [INFO] Fourier spectral method flagged 53 anomalies
# [INFO] Savitzky-Golay flagged 8 anomalies
# [INFO] Total pop-ins detected by selected methods: 147
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain9_6um_indent03_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain9_6um_indent03_HL_QS_LC.txt: 16391 × 3
# [INFO] Removed first 808 points up to minimum Load (-123.05)
# [INFO] Auto-rescaled at index 687, load=146.43 > 127.88, shift=6.8 nm
# [INFO] Flagged contact point at index 687
# [INFO] Removed 687 rows before contact point (Depth < 0)
# ✅ Done: grain10_6um_indent03_HL_QS_LC.txt (Pop-ins detected: 147)
# Processing grain9_6um_indent03_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 15 anomalies
# [INFO] CNN flagged 140 anomalies
# [INFO] Fourier spectral method flagged 24 anomalies
# [INFO] Savitzky-Golay flagged 30 anomalies
# [INFO] Total pop-ins detected by selected methods: 183
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain1_6um_indent03_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain1_6um_indent03_HL_QS_LC.txt: 16392 × 3
# [INFO] Removed first 864 points up to minimum Load (-405.38)
# [INFO] Auto-rescaled at index 635, load=295.54 > 280.64, shift=-22.9 nm
# [INFO] Flagged contact point at index 635
# [INFO] Removed 635 rows before contact point (Depth < 0)
# ✅ Done: grain9_6um_indent03_HL_QS_LC.txt (Pop-ins detected: 183)
# Processing grain1_6um_indent03_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 15 anomalies
# [INFO] CNN flagged 87 anomalies
# [INFO] Fourier spectral method flagged 73 anomalies
# [INFO] Savitzky-Golay flagged 3 anomalies
# [INFO] Total pop-ins detected by selected methods: 174
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain10_6um_indent02_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain10_6um_indent02_HL_QS_LC.txt: 16344 × 3
# [INFO] Removed first 805 points up to minimum Load (-128.31)
# [INFO] Auto-rescaled at index 643, load=190.54 > 138.39, shift=-27.9 nm
# [INFO] Flagged contact point at index 643
# [INFO] Removed 643 rows before contact point (Depth < 0)
# ✅ Done: grain1_6um_indent03_HL_QS_LC.txt (Pop-ins detected: 174)
# Processing grain10_6um_indent02_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 15 anomalies
# [INFO] CNN flagged 82 anomalies
# [INFO] Fourier spectral method flagged 39 anomalies
# [INFO] Savitzky-Golay flagged 13 anomalies
# [INFO] Total pop-ins detected by selected methods: 140
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain6_6um_indent03_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain6_6um_indent03_HL_QS_LC.txt: 16385 × 3
# [INFO] Removed first 315 points up to minimum Load (-129.80)
# [INFO] Auto-rescaled at index 1176, load=197.18 > 131.21, shift=-23.6 nm
# [INFO] Flagged contact point at index 1176
# [INFO] Removed 1176 rows before contact point (Depth < 0)
# ✅ Done: grain10_6um_indent02_HL_QS_LC.txt (Pop-ins detected: 140)
# Processing grain6_6um_indent03_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 15 anomalies
# [INFO] CNN flagged 88 anomalies
# [INFO] Fourier spectral method flagged 49 anomalies
# [INFO] Savitzky-Golay flagged 0 anomalies
# [INFO] Total pop-ins detected by selected methods: 149
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain1_6um_indent02_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain1_6um_indent02_HL_QS_LC.txt: 16389 × 3
# [INFO] Removed first 886 points up to minimum Load (-147.52)
# [INFO] Auto-rescaled at index 609, load=384.21 > 313.12, shift=-24.3 nm
# [INFO] Flagged contact point at index 609
# [INFO] Removed 609 rows before contact point (Depth < 0)
# ✅ Done: grain6_6um_indent03_HL_QS_LC.txt (Pop-ins detected: 149)
# Processing grain1_6um_indent02_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 15 anomalies
# [INFO] CNN flagged 158 anomalies
# [INFO] Fourier spectral method flagged 45 anomalies
# [INFO] Savitzky-Golay flagged 6 anomalies
# [INFO] Total pop-ins detected by selected methods: 216
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain7_6um_indent01_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain7_6um_indent01_HL_QS_LC.txt: 16360 × 3
# [INFO] Removed first 754 points up to minimum Load (-128.38)
# [INFO] Auto-rescaled at index 712, load=116.97 > 97.90, shift=5.4 nm
# [INFO] Flagged contact point at index 712
# [INFO] Removed 712 rows before contact point (Depth < 0)
# ✅ Done: grain1_6um_indent02_HL_QS_LC.txt (Pop-ins detected: 216)
# Processing grain7_6um_indent01_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 10 anomalies
# [INFO] CNN flagged 109 anomalies
# [INFO] Fourier spectral method flagged 42 anomalies
# [INFO] Savitzky-Golay flagged 3 anomalies
# [INFO] Total pop-ins detected by selected methods: 155
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain9_6um_indent02_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain9_6um_indent02_HL_QS_LC.txt: 16400 × 3
# [INFO] Removed first 897 points up to minimum Load (-117.26)
# [INFO] Auto-rescaled at index 608, load=169.38 > 143.68, shift=6.8 nm
# [INFO] Flagged contact point at index 608
# [INFO] Removed 608 rows before contact point (Depth < 0)
# ✅ Done: grain7_6um_indent01_HL_QS_LC.txt (Pop-ins detected: 155)
# Processing grain9_6um_indent02_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 13 anomalies
# [INFO] CNN flagged 72 anomalies
# [INFO] Fourier spectral method flagged 31 anomalies
# [INFO] Savitzky-Golay flagged 31 anomalies
# [INFO] Total pop-ins detected by selected methods: 123
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain2_6um_indent01_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain2_6um_indent01_HL_QS_LC.txt: 16397 × 3
# [INFO] Removed first 394 points up to minimum Load (-4.97)
# [INFO] Auto-rescaled at index 1108, load=481.98 > 433.81, shift=-26.9 nm
# [INFO] Flagged contact point at index 1108
# [INFO] Removed 1108 rows before contact point (Depth < 0)
# ✅ Done: grain9_6um_indent02_HL_QS_LC.txt (Pop-ins detected: 123)
# Processing grain2_6um_indent01_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 15 anomalies
# [INFO] CNN flagged 102 anomalies
# [INFO] Fourier spectral method flagged 92 anomalies
# [INFO] Savitzky-Golay flagged 5 anomalies
# [INFO] Total pop-ins detected by selected methods: 210
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain3_6um_indent03_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain3_6um_indent03_HL_QS_LC.txt: 16359 × 5
# [INFO] Removed first 964 points up to minimum Load (-391.02)
# [INFO] Auto-rescaled at index 501, load=200.50 > 129.16, shift=-23.3 nm
# [INFO] Flagged contact point at index 501
# [INFO] Removed 501 rows before contact point (Depth < 0)
# ✅ Done: grain2_6um_indent01_HL_QS_LC.txt (Pop-ins detected: 210)
# Processing grain3_6um_indent03_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 14 anomalies
# [INFO] CNN flagged 109 anomalies
# [INFO] Fourier spectral method flagged 57 anomalies
# [INFO] Savitzky-Golay flagged 0 anomalies
# [INFO] Total pop-ins detected by selected methods: 175
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain4_6um_indent03_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain4_6um_indent03_HL_QS_LC.txt: 16391 × 3
# [INFO] Removed first 771 points up to minimum Load (-86.84)
# [INFO] Auto-rescaled at index 725, load=278.81 > 216.56, shift=-26.1 nm
# [INFO] Flagged contact point at index 725
# [INFO] Removed 725 rows before contact point (Depth < 0)
# ✅ Done: grain3_6um_indent03_HL_QS_LC.txt (Pop-ins detected: 175)
# Processing grain4_6um_indent03_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 15 anomalies
# [INFO] CNN flagged 92 anomalies
# [INFO] Fourier spectral method flagged 25 anomalies
# [INFO] Savitzky-Golay flagged 18 anomalies
# [INFO] Total pop-ins detected by selected methods: 135
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain4_6um_indent04_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain4_6um_indent04_HL_QS_LC.txt: 16398 × 3
# [INFO] Removed first 875 points up to minimum Load (-28.87)
# [INFO] Auto-rescaled at index 628, load=309.08 > 295.82, shift=-25.8 nm
# [INFO] Flagged contact point at index 628
# [INFO] Removed 628 rows before contact point (Depth < 0)
# ✅ Done: grain4_6um_indent03_HL_QS_LC.txt (Pop-ins detected: 135)
# Processing grain4_6um_indent04_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 15 anomalies
# [INFO] CNN flagged 122 anomalies
# [INFO] Fourier spectral method flagged 41 anomalies
# [INFO] Savitzky-Golay flagged 0 anomalies
# [INFO] Total pop-ins detected by selected methods: 175
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain3_6um_indent02_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain3_6um_indent02_HL_QS_LC.txt: 16386 × 3
# [INFO] Removed first 887 points up to minimum Load (-180.04)
# [INFO] Auto-rescaled at index 609, load=581.62 > 521.96, shift=-17.4 nm
# [INFO] Flagged contact point at index 609
# [INFO] Removed 609 rows before contact point (Depth < 0)
# ✅ Done: grain4_6um_indent04_HL_QS_LC.txt (Pop-ins detected: 175)
# Processing grain3_6um_indent02_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 15 anomalies
# [INFO] CNN flagged 106 anomalies
# [INFO] Fourier spectral method flagged 39 anomalies
# [INFO] Savitzky-Golay flagged 16 anomalies
# [INFO] Total pop-ins detected by selected methods: 170
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain5_6um_indent01_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain5_6um_indent01_HL_QS_LC.txt: 16392 × 3
# [INFO] Removed first 514 points up to minimum Load (-94.54)
# [INFO] Auto-rescaled at index 981, load=172.06 > 155.08, shift=-29.4 nm
# [INFO] Flagged contact point at index 981
# [INFO] Removed 981 rows before contact point (Depth < 0)
# ✅ Done: grain3_6um_indent02_HL_QS_LC.txt (Pop-ins detected: 170)
# Processing grain5_6um_indent01_HL_QS_LC.txt...
# [INFO] IsolationForest flagged 15 anomalies
# [INFO] CNN flagged 117 anomalies
# [INFO] Fourier spectral method flagged 25 anomalies
# [INFO] Savitzky-Golay flagged 14 anomalies
# [INFO] Total pop-ins detected by selected methods: 157
# ✅ Done: grain5_6um_indent01_HL_QS_LC.txt (Pop-ins detected: 157)

# %% [markdown]
# ## Show the Visualizations

# %%
# Load all PNGs from output folder
image_paths = sorted(output_dir.glob("*.png"))

# Only proceed if there are images
if image_paths:
    n_images = len(image_paths)
    print(f"Found {n_images} plots in output folder.")
    n_cols = 3 # Number of columns for the plot grid
    n_rows = math.ceil(n_images / n_cols)

    fig, axs = plt.subplots(n_rows, n_cols, figsize=(12, 6 * n_rows))

    for ax, img_path in zip(axs.flatten(), image_paths):
        img = Image.open(img_path)
        ax.imshow(img)
        ax.set_title(img_path.stem)
        ax.axis('off')

    # Hide any unused subplots
    for ax in axs.flatten()[n_images:]:
        ax.axis('off')

    plt.tight_layout()
    plt.show()
else:
    print("No plots found in output folder.")
# Out:
# Found 30 plots in output folder.
