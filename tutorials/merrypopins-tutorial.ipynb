# %% [markdown]
# # merrypopins Tutorial

# %%
# Change to project root (parent directory) This step is necessary to ensure that the script runs from the correct context.
# %cd ..

from pathlib import Path

# Check if current directory is 'merrypopins'
if Path.cwd().name != "merrypopins":
    print("Error: You are not in the project root directory.")
    print("Please change to the project root directory and try again.")
# Out:
# /Users/cacar/Desktop/University Documents and Books/Utrecht-Uni-Master-Applied-Data-Science/Thesis/merrypopins

# %% [markdown]
# ## Installation

# %% [markdown]
# If you already have `merrypopins` installed, you can skip this step.

# %%
# !python3 -m pip install --upgrade pip
# !pip uninstall merrypopins -y
# !python3 -m pip install -e .
# Out:
# Requirement already satisfied: pip in /opt/anaconda3/lib/python3.12/site-packages (25.1.1)
# Found existing installation: merrypopins 0.2.0
# Uninstalling merrypopins-0.2.0:
#   Successfully uninstalled merrypopins-0.2.0
# Obtaining file:///Users/cacar/Desktop/University%20Documents%20and%20Books/Utrecht-Uni-Master-Applied-Data-Science/Thesis/merrypopins
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib>=3.10.3 in /opt/anaconda3/lib/python3.12/site-packages (from merrypopins==0.2.0) (3.10.3)
# Requirement already satisfied: numpy<2.5,>=1.23 in /opt/anaconda3/lib/python3.12/site-packages (from merrypopins==0.2.0) (1.26.4)
# Requirement already satisfied: pandas>=2.2.3 in /opt/anaconda3/lib/python3.12/site-packages (from merrypopins==0.2.0) (2.2.3)
# Requirement already satisfied: scipy>=1.15.3 in /opt/anaconda3/lib/python3.12/site-packages (from merrypopins==0.2.0) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.6.1 in /opt/anaconda3/lib/python3.12/site-packages (from merrypopins==0.2.0) (1.6.1)
# Requirement already satisfied: tensorflow>=2.16.2 in /opt/anaconda3/lib/python3.12/site-packages (from merrypopins==0.2.0) (2.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.10.3->merrypopins==0.2.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.10.3->merrypopins==0.2.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.10.3->merrypopins==0.2.0) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.10.3->merrypopins==0.2.0) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.10.3->merrypopins==0.2.0) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.10.3->merrypopins==0.2.0) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.10.3->merrypopins==0.2.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.10.3->merrypopins==0.2.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=2.2.3->merrypopins==0.2.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=2.2.3->merrypopins==0.2.0) (2024.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.10.3->merrypopins==0.2.0) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=1.6.1->merrypopins==0.2.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=1.6.1->merrypopins==0.2.0) (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.2.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.2.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.2.0) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.2.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.2.0) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.2.0) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.2.0) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.2.0) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.2.0) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.2.0) (4.25.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.2.0) (2.32.3)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.2.0) (75.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.2.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.2.0) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.2.0) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.2.0) (1.69.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.2.0) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow>=2.16.2->merrypopins==0.2.0) (3.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow>=2.16.2->merrypopins==0.2.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow>=2.16.2->merrypopins==0.2.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow>=2.16.2->merrypopins==0.2.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow>=2.16.2->merrypopins==0.2.0) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.16.2->merrypopins==0.2.0) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.16.2->merrypopins==0.2.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.16.2->merrypopins==0.2.0) (3.0.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow>=2.16.2->merrypopins==0.2.0) (0.44.0)
# Requirement already satisfied: rich in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow>=2.16.2->merrypopins==0.2.0) (13.9.4)
# Requirement already satisfied: namex in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow>=2.16.2->merrypopins==0.2.0) (0.0.8)
# Requirement already satisfied: optree in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow>=2.16.2->merrypopins==0.2.0) (0.13.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow>=2.16.2->merrypopins==0.2.0) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow>=2.16.2->merrypopins==0.2.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow>=2.16.2->merrypopins==0.2.0) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow>=2.16.2->merrypopins==0.2.0) (0.1.0)
# Building wheels for collected packages: merrypopins
#   Building editable for merrypopins (pyproject.toml) ... done
#   Created wheel for merrypopins: filename=merrypopins-0.2.0-0.editable-py3-none-any.whl size=18160 sha256=36873c14600959134d881d825189bf8dce549e8abbca9dfc5d9439cbaba580b6
#   Stored in directory: /private/var/folders/bg/vndfz9xx467c3blfn0k7mlbc0000gn/T/pip-ephem-wheel-cache-lh672_c9/wheels/82/0f/fb/e0ceb84d648e8984895addbac076998d8e2027912ad09ba4e4
# Successfully built merrypopins
# Installing collected packages: merrypopins
# Successfully installed merrypopins-0.2.0

# %% [markdown]
# ## Import Packages

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
from PIL import Image
from pathlib import Path

from merrypopins.load_datasets import load_txt, load_tdm
from merrypopins.preprocess import default_preprocess
from merrypopins.locate import (
    default_locate,
    detect_popins_iforest,
    detect_popins_cnn,
    detect_popins_fd_fourier,
    detect_popins_savgol
)
from merrypopins.make_dataset import merrypopins_pipeline
# Out:
# 2025-06-06 20:03:21.121144: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Load Raw Data

# %%
# 2.1 Point this at one of your .txt measurement files
txt_path = Path("datasets/6microntip_slowloading/grain9_6um_indent03_HL_QS_LC.txt")
df = load_txt(txt_path)

# 2.2 Peek at the first few rows
df.head()
# Out:
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain9_6um_indent03_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain9_6um_indent03_HL_QS_LC.txt: 16391 × 3
#    Depth (nm)    Load (µN)  Time (s)
# 0   27.553054  1970.863069  0.000000
# 1   27.699882  2057.642476  0.005005
# 2   27.409630  2105.476271  0.010010
# 3   27.550630  2050.874908  0.015014
# 4   27.360660  2041.534181  0.020019

# %%
# 2.3 Metadata on the txt file
print("Timestamp:   ", df.attrs["timestamp"])
print("Num points:  ", df.attrs["num_points"])
# Out:
# Timestamp:    Wed Apr 16 11:27:39 2025
# Num points:   16391

# %% [markdown]
# ## Load TDM Metadata

# %%
tdm_meta_file = Path("datasets/6microntip_slowloading/grain1_6um_indent01_HL_QS_LC.tdm")
df_tdm_meta_root, df_tdm_meta_channels = load_tdm(tdm_meta_file)
# Out:
# [INFO] Loaded TDM metadata grain1_6um_indent01_HL_QS_LC.tdm: 47 channels

# %%
df_tdm_meta_root.head()
# Out:
#             root_name        root_description          root_title root_author  \
# 0  Hysitron Data File  Quasi-static Test Data  Hysitron Data File  localadmin
#
#   Acquisition_Actuation_Gain Acquisition_Actuation_Percentage  \
# 0                         15              0.00301045850968697
#
#   Acquisition_Adaptive_FB_Gain Acquisition_ADC0_Offset__V__  \
# 0                          0.5            -3.53889723777893
#
#   Acquisition_ADC3_Offset__V__                Acquisition_Area_Function_Name  \
# 0             5.68998800731816  newHLConi6_TAF_10-04-25_MCA2_TAF2_MC0550.ara
#
#    ... Uncertainty_Quasi_Analysis_Force_Shift__µN__  \
# 0  ...                             105.757206912521
#
#   Uncertainty_Quasi_Analysis_Hardness__GPa__  \
# 0                                          0
#
#   Uncertainty_Quasi_Analysis_Indentation_Modulus__GPa__  \
# 0                                                  0
#
#   Uncertainty_Quasi_Analysis_Martens_Area__nm~nm__  \
# 0                                                0
#
#   Uncertainty_Quasi_Analysis_Martens_Hardness__GPa__  \
# 0                                                  0
#
#   Uncertainty_Quasi_Analysis_Max_Depth_For_Hardness__nm__  \
# 0                                                  0
#
#   Uncertainty_Quasi_Analysis_Max_Fitted_Depth__nm__  \
# 0                                                 0
#
#   Uncertainty_Quasi_Analysis_Max_Force__µN__  \
# 0                                          0
#
#   Uncertainty_Quasi_Analysis_Max_Force_For_Hardness__µN__  \
# 0                                                  0
#
#   Uncertainty_Quasi_Analysis_Reduced_Modulus__GPa__
# 0                                                 0
#
# [1 rows x 368 columns]

# %% [markdown]
# As we can see the metadata root data have 368 columns we can transpose it to have a better view of the data.

# %%
df_tdm_meta_root = df_tdm_meta_root.T.reset_index()
df_tdm_meta_root.columns = ['attribute', 'value']

# %%
# Let's take a look at the first 10 rows of the metadata root DataFrame
df_tdm_meta_root.head(10)
# Out:
#                           attribute  \
# 0                         root_name
# 1                  root_description
# 2                        root_title
# 3                       root_author
# 4        Acquisition_Actuation_Gain
# 5  Acquisition_Actuation_Percentage
# 6      Acquisition_Adaptive_FB_Gain
# 7      Acquisition_ADC0_Offset__V__
# 8      Acquisition_ADC3_Offset__V__
# 9    Acquisition_Area_Function_Name
#
#                                           value
# 0                            Hysitron Data File
# 1                        Quasi-static Test Data
# 2                            Hysitron Data File
# 3                                    localadmin
# 4                                            15
# 5                           0.00301045850968697
# 6                                           0.5
# 7                             -3.53889723777893
# 8                              5.68998800731816
# 9  newHLConi6_TAF_10-04-25_MCA2_TAF2_MC0550.ara

# %%
# Metadata channels
df_tdm_meta_channels.head(50)
# Out:
#                                     group channel_id                    name  \
# 0             Indentation All Data Points      usi59               Test Time
# 1             Indentation Averaged Values      usi60               Test Time
# 2   Indentation Standard Deviation Values      usi61               Test Time
# 3             Indentation All Data Points      usi62            Indent Disp.
# 4             Indentation Averaged Values      usi63            Indent Disp.
# 5   Indentation Standard Deviation Values      usi64            Indent Disp.
# 6             Indentation All Data Points      usi65             Indent Load
# 7             Indentation Averaged Values      usi66             Indent Load
# 8   Indentation Standard Deviation Values      usi67             Indent Load
# 9             Indentation All Data Points      usi68      Indent Disp. Volt.
# 10            Indentation Averaged Values      usi69      Indent Disp. Volt.
# 11  Indentation Standard Deviation Values      usi70      Indent Disp. Volt.
# 12            Indentation All Data Points      usi71  Indent Act. Load Volt.
# 13            Indentation Averaged Values      usi72  Indent Act. Load Volt.
# 14  Indentation Standard Deviation Values      usi73  Indent Act. Load Volt.
# 15            Indentation All Data Points      usi74      Piezo Displacement
# 16            Indentation Averaged Values      usi75      Piezo Displacement
# 17  Indentation Standard Deviation Values      usi76      Piezo Displacement
# 18            Indentation All Data Points      usi77   Loadcell Displacement
# 19            Indentation Averaged Values      usi78   Loadcell Displacement
# 20  Indentation Standard Deviation Values      usi79   Loadcell Displacement
# 21            Indentation All Data Points      usi80             Piezo Volt.
# 22            Indentation Averaged Values      usi81             Piezo Volt.
# 23  Indentation Standard Deviation Values      usi82             Piezo Volt.
# 24                               Segments      usi83            Segment Type
# 25                               Segments      usi84      Segment Begin Time
# 26                               Segments      usi85        Segment End Time
# 27                               Segments      usi86            Segment Time
# 28                               Segments      usi87    Segment Begin Demand
# 29                               Segments      usi88      Segment End Demand
# 30                               Segments      usi89         Segment FB Mode
# 31                               Segments      usi90          Segment Points
# 32               Approach All Data Points      usi91           Approach Time
# 33               Approach Averaged Values      usi92           Approach Time
# 34     Approach Standard Deviation Values      usi93           Approach Time
# 35               Approach All Data Points      usi94      Motor Displacement
# 36               Approach Averaged Values      usi95      Motor Displacement
# 37     Approach Standard Deviation Values      usi96      Motor Displacement
# 38               Approach All Data Points      usi97            Sample Force
# 39               Approach Averaged Values      usi98            Sample Force
# 40     Approach Standard Deviation Values      usi99            Sample Force
# 41                  Drift All Data Points     usi100              Drift Time
# 42                  Drift Averaged Values     usi101              Drift Time
# 43        Drift Standard Deviation Values     usi102              Drift Time
# 44                  Drift All Data Points     usi103      Drift Displacement
# 45                  Drift Averaged Values     usi104      Drift Displacement
# 46        Drift Standard Deviation Values     usi105      Drift Displacement
#
#       unit                                        description   datatype  \
# 0        s                                          Test Time  DT_DOUBLE
# 1        s                                          Test Time  DT_DOUBLE
# 2        s                                          Test Time  DT_DOUBLE
# 3       nm                                Indent Displacement  DT_DOUBLE
# 4       nm                                Indent Displacement  DT_DOUBLE
# 5       nm                                Indent Displacement  DT_DOUBLE
# 6       µN                                        Indent Load  DT_DOUBLE
# 7       µN                                        Indent Load  DT_DOUBLE
# 8       µN                                        Indent Load  DT_DOUBLE
# 9        V                        Indent Displacement Voltage  DT_DOUBLE
# 10       V                        Indent Displacement Voltage  DT_DOUBLE
# 11       V                        Indent Displacement Voltage  DT_DOUBLE
# 12       V                      Indent Actuation Load Voltage  DT_DOUBLE
# 13       V                      Indent Actuation Load Voltage  DT_DOUBLE
# 14       V                      Indent Actuation Load Voltage  DT_DOUBLE
# 15      nm                                 Piezo Displacement  DT_DOUBLE
# 16      nm                                 Piezo Displacement  DT_DOUBLE
# 17      nm                                 Piezo Displacement  DT_DOUBLE
# 18      nm                              Loadcell Displacement  DT_DOUBLE
# 19      nm                              Loadcell Displacement  DT_DOUBLE
# 20      nm                              Loadcell Displacement  DT_DOUBLE
# 21       V                                      Piezo Voltage  DT_DOUBLE
# 22       V                                      Piezo Voltage  DT_DOUBLE
# 23       V                                      Piezo Voltage  DT_DOUBLE
# 24                      0 - Quasi, 1 - nanoDMA, 2 - Reference    DT_LONG
# 25       s                                 Segment Begin Time  DT_DOUBLE
# 26       s                                   Segment End Time  DT_DOUBLE
# 27       s                                       Segment Time  DT_DOUBLE
# 28      µN                               Segment Begin Demand  DT_DOUBLE
# 29      µN                                 Segment End Demand  DT_DOUBLE
# 30          0 - Open Loop, 1 - Displacement Control, 5 - L...    DT_LONG
# 31  Points                                Segment Data Points    DT_LONG
# 32       s                                      Approach Time  DT_DOUBLE
# 33       s                                      Approach Time  DT_DOUBLE
# 34       s                                      Approach Time  DT_DOUBLE
# 35      mm                                 Motor Displacement  DT_DOUBLE
# 36      mm                                 Motor Displacement  DT_DOUBLE
# 37      mm                                 Motor Displacement  DT_DOUBLE
# 38      uN                                       Sample Force  DT_DOUBLE
# 39      uN                                       Sample Force  DT_DOUBLE
# 40      uN                                       Sample Force  DT_DOUBLE
# 41       s                                         Drift Time  DT_DOUBLE
# 42       s                                         Drift Time  DT_DOUBLE
# 43       s                                         Drift Time  DT_DOUBLE
# 44      nm                                 Drift Displacement  DT_DOUBLE
# 45      nm                                 Drift Displacement  DT_DOUBLE
# 46      nm                                 Drift Displacement  DT_DOUBLE
#
#    sequence_id
# 0         usi1
# 1         usi2
# 2         usi3
# 3         usi4
# 4         usi5
# 5         usi6
# 6         usi7
# 7         usi8
# 8         usi9
# 9        usi10
# 10       usi11
# 11       usi12
# 12       usi13
# 13       usi14
# 14       usi15
# 15       usi16
# 16       usi17
# 17       usi18
# 18       usi19
# 19       usi20
# 20       usi21
# 21       usi22
# 22       usi23
# 23       usi24
# 24       usi25
# 25       usi26
# 26       usi27
# 27       usi28
# 28       usi29
# 29       usi30
# 30       usi31
# 31       usi32
# 32       usi33
# 33       usi34
# 34       usi35
# 35       usi36
# 36       usi37
# 37       usi38
# 38       usi39
# 39       usi40
# 40       usi41
# 41       usi42
# 42       usi43
# 43       usi44
# 44       usi45
# 45       usi46
# 46       usi47

# %% [markdown]
# ## Preprocess Data

# %%
# 4.1 Apply the default preprocessing pipeline
df_pre = default_preprocess(df)

# 4.2 Inspect result
df_pre.head()
# Out:
# [INFO] Removed first 808 points up to minimum Load (-123.05)
# [INFO] Auto-rescaled at index 687, load=146.43 > 127.88, shift=6.8 nm
# [INFO] Flagged contact point at index 687
# [INFO] Removed 687 rows before contact point (Depth < 0)
#    Depth (nm)   Load (µN)  Time (s)  contact_point
# 0    0.000000  175.206294  9.958208           True
# 1    1.498740  204.902582  9.968205          False
# 2    3.108329  261.286045  9.978202          False
# 3    4.590940  378.618504  9.988199          False
# 4    6.165765  489.429839  9.998195          False

# %% [markdown]
# ### Plot Raw vs Preprocessed Data

# %%
# 4.3 Plot Raw vs Preprocessed
plt.figure(figsize=(6,4))
plt.plot(df["Depth (nm)"], df["Load (µN)"], '--', alpha=0.5, label="Raw")
plt.plot(df_pre["Depth (nm)"], df_pre["Load (µN)"], '-', label="Preprocessed")
plt.xlabel("Depth (nm)")
plt.ylabel("Load (µN)")
plt.title("Raw vs Preprocessed")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Pop-in Detection

# %% [markdown]
# ### Isolation Forest

# %%
df_if = detect_popins_iforest(df_pre, random_state=42)
# Out:
# [INFO] IsolationForest flagged 14 anomalies

# %%
plt.figure(figsize=(6,4))
plt.plot(df_pre["Depth (nm)"], df_pre["Load (µN)"], label="Preprocessed")
plt.scatter(df_if.loc[df_if["popin_iforest"], "Depth (nm)"],
            df_if.loc[df_if["popin_iforest"], "Load (µN)"],
            c='r', label="IsolationForest", marker='^')
plt.title("Pop-ins: Isolation Forest")
plt.xlabel("Depth (nm)"); plt.ylabel("Load (µN)")
plt.legend(); plt.grid(True); plt.show()

# %% [markdown]
# ### CNN Autoencoder

# %%
df_cnn = detect_popins_cnn(df_pre)
# Out:
# [INFO] CNN flagged 144 anomalies

# %%
plt.figure(figsize=(6,4))
plt.plot(df_pre["Depth (nm)"], df_pre["Load (µN)"], label="Preprocessed")
plt.scatter(df_cnn.loc[df_cnn["popin_cnn"], "Depth (nm)"],
            df_cnn.loc[df_cnn["popin_cnn"], "Load (µN)"],
            c='purple', label="CNN Autoencoder", marker='v')
plt.title("Pop-ins: CNN Autoencoder")
plt.xlabel("Depth (nm)"); plt.ylabel("Load (µN)")
plt.legend(); plt.grid(True); plt.show()

# %% [markdown]
# ### Finite Difference

# %%
df_fd = detect_popins_fd_fourier(df_pre)
# Out:
# [INFO] Fourier spectral method flagged 24 anomalies

# %%
plt.figure(figsize=(6,4))
plt.plot(df_pre["Depth (nm)"], df_pre["Load (µN)"], label="Preprocessed")
plt.scatter(df_fd.loc[df_fd["popin_fd"], "Depth (nm)"],
            df_fd.loc[df_fd["popin_fd"], "Load (µN)"],
            c='orange', label="Finite Difference", marker='x')
plt.title("Pop-ins: Finite Difference")
plt.xlabel("Depth (nm)"); plt.ylabel("Load (µN)")
plt.legend(); plt.grid(True); plt.show()

# %% [markdown]
# ### Savitzky-Golay Derivative

# %%
df_sg = detect_popins_savgol(df_pre)
# Out:
# [INFO] Savitzky-Golay flagged 33 anomalies

# %%
plt.figure(figsize=(6,4))
plt.plot(df_pre["Depth (nm)"], df_pre["Load (µN)"], label="Preprocessed")
plt.scatter(df_sg.loc[df_sg["popin_savgol"], "Depth (nm)"],
            df_sg.loc[df_sg["popin_savgol"], "Load (µN)"],
            c='green', label="Savitzky-Golay", marker='D')
plt.title("Pop-ins: Savitzky-Golay")
plt.xlabel("Depth (nm)"); plt.ylabel("Load (µN)")
plt.legend(); plt.grid(True); plt.show()

# %% [markdown]
# ### All Methods Combined

# %%
df_loc = default_locate(df_pre, trim_margin=30)
# Out:
# [INFO] IsolationForest flagged 12 anomalies
# [INFO] CNN flagged 142 anomalies
# [INFO] Fourier spectral method flagged 24 anomalies
# [INFO] Savitzky-Golay flagged 30 anomalies
# [INFO] Total pop-ins detected by selected methods: 186

# %%
df_loc.head()
# Out:
#    Depth (nm)   Load (µN)  Time (s)  contact_point  popin_iforest  popin_cnn  \
# 0    0.000000  175.206294  9.958208           True          False      False
# 1    1.498740  204.902582  9.968205          False          False      False
# 2    3.108329  261.286045  9.978202          False          False      False
# 3    4.590940  378.618504  9.988199          False          False      False
# 4    6.165765  489.429839  9.998195          False          False      False
#
#    popin_fd  popin_savgol  popin popin_methods  popin_score  popin_confident
# 0     False         False  False                          0            False
# 1     False         False  False                          0            False
# 2     False         False  False                          0            False
# 3     False         False  False                          0            False
# 4     False         False  False                          0            False

# %%
plt.figure(figsize=(8,6))
plt.plot(df_loc["Depth (nm)"], df_loc["Load (µN)"], label="Preprocessed", alpha=0.4, color='orange')

# Color-coded method detections
colors = {
    "popin_iforest": 'red',
    "popin_cnn": 'purple',
    "popin_fd": 'darkorange',
    "popin_savgol": 'green'
}
markers = {
    "popin_iforest": '^',
    "popin_cnn": 'v',
    "popin_fd": 'x',
    "popin_savgol": 'D'
}

for method, color in colors.items():
    mdf = df_loc[df_loc[method]]
    plt.scatter(mdf["Depth (nm)"], mdf["Load (µN)"],
                c=color, label=method.replace("popin_", "").capitalize(),
                marker=markers[method], alpha=0.7)

# Highlight confident detections
confident = df_loc[df_loc["popin_confident"]]
plt.scatter(confident["Depth (nm)"], confident["Load (µN)"],
            edgecolors='k', facecolors='none', label="Majority Vote (2+)", s=100, linewidths=1.5)

plt.xlabel("Depth (nm)"); plt.ylabel("Load (µN)")
plt.title("Pop-in Detections by All Methods")
plt.legend(); plt.grid(True); plt.tight_layout(); plt.show()

# %% [markdown]
# #### Default Locate More Strict Threshold

# %%
# 1. Tighter thresholds (more sensitive, may yield more false positives)
df_loc_strict = default_locate(
    df_pre,
    iforest_contamination=0.002,     # higher contamination → more anomalies
    cnn_threshold_multiplier=3.0,    # lower multiplier → more CNN anomalies
    fd_threshold=2.0,                # lower std threshold for FD
    savgol_threshold=2.0             # lower std threshold for Savitzky-Golay
)
# Out:
# [INFO] IsolationForest flagged 26 anomalies
# [INFO] CNN flagged 295 anomalies
# [INFO] Fourier spectral method flagged 47 anomalies
# [INFO] Savitzky-Golay flagged 41 anomalies
# [INFO] Total pop-ins detected by selected methods: 368

# %%
plt.figure(figsize=(8,6))
plt.plot(df_loc_strict["Depth (nm)"], df_loc_strict["Load (µN)"], label="Preprocessed", alpha=0.4, color='orange')

colors = {
    "popin_iforest": 'red',
    "popin_cnn": 'purple',
    "popin_fd": 'darkorange',
    "popin_savgol": 'green'
}
markers = {
    "popin_iforest": '^',
    "popin_cnn": 'v',
    "popin_fd": 'x',
    "popin_savgol": 'D'
}

for method, color in colors.items():
    mdf = df_loc_strict[df_loc_strict[method]]
    plt.scatter(mdf["Depth (nm)"], mdf["Load (µN)"],
                c=color, label=method.replace("popin_", "").capitalize(),
                marker=markers[method], alpha=0.7)

confident = df_loc_strict[df_loc_strict["popin_confident"]]
plt.scatter(confident["Depth (nm)"], confident["Load (µN)"],
            edgecolors='k', facecolors='none', label="Majority Vote (2+)", s=100, linewidths=1.5)

plt.xlabel("Depth (nm)"); plt.ylabel("Load (µN)")
plt.title("Stricter Thresholds - Pop-in Detections")
plt.legend(); plt.grid(True); plt.tight_layout(); plt.show()

# %% [markdown]
# #### Default Locate More Lenient Threshold

# %%
# 2. Looser thresholds (more conservative)
df_loc_loose = default_locate(
    df_pre,
    iforest_contamination=0.0005,
    cnn_threshold_multiplier=6.0,
    fd_threshold=4.0,
    savgol_threshold=4.0
)
# Out:
# [INFO] IsolationForest flagged 8 anomalies
# [INFO] CNN flagged 103 anomalies
# [INFO] Fourier spectral method flagged 19 anomalies
# [INFO] Savitzky-Golay flagged 26 anomalies
# [INFO] Total pop-ins detected by selected methods: 136

# %%
plt.figure(figsize=(8,6))
plt.plot(df_loc_loose["Depth (nm)"], df_loc_loose["Load (µN)"], label="Preprocessed", alpha=0.4, color='orange')

for method, color in colors.items():
    mdf = df_loc_loose[df_loc_loose[method]]
    plt.scatter(mdf["Depth (nm)"], mdf["Load (µN)"],
                c=color, label=method.replace("popin_", "").capitalize(),
                marker=markers[method], alpha=0.7)

confident = df_loc_loose[df_loc_loose["popin_confident"]]
plt.scatter(confident["Depth (nm)"], confident["Load (µN)"],
            edgecolors='k', facecolors='none', label="Majority Vote (2+)", s=100, linewidths=1.5)

plt.xlabel("Depth (nm)"); plt.ylabel("Load (µN)")
plt.title("Looser Thresholds - Pop-in Detections")
plt.legend(); plt.grid(True); plt.tight_layout(); plt.show()

# %% [markdown]
# #### Comparison of Looser and Stricter Thresholds

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4), sharey=True)

# Plot strict
ax[0].plot(df_pre["Depth (nm)"], df_pre["Load (µN)"], color="gray", alpha=0.4, label="Preprocessed")
ax[0].scatter(df_loc_strict[df_loc_strict["popin"]]["Depth (nm)"],
              df_loc_strict[df_loc_strict["popin"]]["Load (µN)"],
              c="C3", s=30, label="Strict pop-ins")
ax[0].set_title("Stricter Thresholds")
ax[0].set_xlabel("Depth (nm)")
ax[0].set_ylabel("Load (µN)")
ax[0].legend()
ax[0].grid(True)

# Plot loose
ax[1].plot(df_pre["Depth (nm)"], df_pre["Load (µN)"], color="gray", alpha=0.4, label="Preprocessed")
ax[1].scatter(df_loc_loose[df_loc_loose["popin"]]["Depth (nm)"],
              df_loc_loose[df_loc_loose["popin"]]["Load (µN)"],
              c="C2", s=30, label="Loose pop-ins")
ax[1].set_title("Looser Thresholds")
ax[1].set_xlabel("Depth (nm)")
ax[1].legend()
ax[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Locate Without Preprocessing

# %%
df_loc_without_preprocessing = default_locate(df)
# Out:
# [INFO] IsolationForest flagged 15 anomalies
# [INFO] CNN flagged 157 anomalies
# [INFO] Fourier spectral method flagged 25 anomalies
# [INFO] Savitzky-Golay flagged 37 anomalies
# [INFO] Total pop-ins detected by selected methods: 207

# %%
plt.figure(figsize=(8,6))
plt.plot(df_loc_without_preprocessing["Depth (nm)"], df_loc_without_preprocessing["Load (µN)"], label="Preprocessed", alpha=0.4, color='orange')

# Color-coded method detections
colors = {
    "popin_iforest": 'red',
    "popin_cnn": 'purple',
    "popin_fd": 'darkorange',
    "popin_savgol": 'green'
}
markers = {
    "popin_iforest": '^',
    "popin_cnn": 'v',
    "popin_fd": 'x',
    "popin_savgol": 'D'
}

for method, color in colors.items():
    mdf = df_loc_without_preprocessing[df_loc_without_preprocessing[method]]
    plt.scatter(mdf["Depth (nm)"], mdf["Load (µN)"],
                c=color, label=method.replace("popin_", "").capitalize(),
                marker=markers[method], alpha=0.7)

# Highlight confident detections
confident = df_loc_without_preprocessing[df_loc_without_preprocessing["popin_confident"]]
plt.scatter(confident["Depth (nm)"], confident["Load (µN)"],
            edgecolors='k', facecolors='none', label="Majority Vote (2+)", s=100, linewidths=1.5)

plt.xlabel("Depth (nm)"); plt.ylabel("Load (µN)")
plt.title("Pop-in Detections without Preprocessing by All Methods")
plt.legend(); plt.grid(True); plt.tight_layout(); plt.show()

# %% [markdown]
# # MerryPopins Pipeline

# %%
# Define the text file that will be processed and output directory that will contain the visualization
text_file = Path("datasets/6microntip_slowloading/grain9_6um_indent03_HL_QS_LC.txt")
output_dir = Path("visualisations/6microntip_slowloading/grain9_6um_indent03_HL_QS_LC")

# %%
# Make sure output directory exists
output_dir.mkdir(parents=True, exist_ok=True)

# %%
# Run the merrypopins pipeline
df_pipeline = merrypopins_pipeline(
    text_file,
    save_plot_dir=output_dir,
    trim_margin=30
)
# Out:
# [WARNING] UTF-8 decode failed for datasets/6microntip_slowloading/grain9_6um_indent03_HL_QS_LC.txt, falling back to Latin-1
# [INFO] Loaded TXT data grain9_6um_indent03_HL_QS_LC.txt: 16391 × 3
# [INFO] Removed first 808 points up to minimum Load (-123.05)
# [INFO] Auto-rescaled at index 687, load=146.43 > 127.88, shift=6.8 nm
# [INFO] Flagged contact point at index 687
# [INFO] Removed 687 rows before contact point (Depth < 0)
# [INFO] IsolationForest flagged 15 anomalies
# [INFO] CNN flagged 147 anomalies
# [INFO] Fourier spectral method flagged 24 anomalies
# [INFO] Savitzky-Golay flagged 30 anomalies
# [INFO] Total pop-ins detected by selected methods: 190

# %%
# Show the first few rows of the processed DataFrame
df_pipeline.head()
# Out:
#    Depth (nm)   Load (µN)  Time (s)  contact_point  popin_iforest  popin_cnn  \
# 0    0.000000  175.206294  9.958208           True          False      False
# 1    1.498740  204.902582  9.968205          False          False      False
# 2    3.108329  261.286045  9.978202          False          False      False
# 3    4.590940  378.618504  9.988199          False          False      False
# 4    6.165765  489.429839  9.998195          False          False      False
#
#    popin_fd  popin_savgol  popin popin_methods  popin_score  popin_confident
# 0     False         False  False                          0            False
# 1     False         False  False                          0            False
# 2     False         False  False                          0            False
# 3     False         False  False                          0            False
# 4     False         False  False                          0            False

# %%
# Load all PNGs from output folder
image_paths = sorted(output_dir.glob("*.png"))

# Only proceed if there are images
if image_paths:
    img = Image.open(image_paths[0])
    plt.figure(figsize=(12, 6))
    plt.imshow(img)
    plt.title(image_paths[0].stem)
    plt.axis('off')
    plt.show()
else:
    print("No plots found in output folder.")
